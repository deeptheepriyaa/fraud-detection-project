# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv("C:/Users/mrnde/fraud-detection-project/data/creditcard_small.csv")

# Check class distribution
plt.figure(figsize=(6,4))
sns.countplot(x="Class", data=df)
plt.title("Class Distribution (0 = Non-Fraud, 1 = Fraud)")
plt.show()

# Show dataset info
print(df.info())
print(df.head())

# Plot transaction amounts
plt.figure(figsize=(10,5))
sns.histplot(df['Amount'], bins=50, kde=True)
plt.title("Transaction Amount Distribution")
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2848 entries, 0 to 2847
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    2848 non-null   float64
#  1   V1      2848 non-null   float64
#  2   V2      2848 non-null   float64
#  3   V3      2848 non-null   float64
#  4   V4      2848 non-null   float64
#  5   V5      2848 non-null   float64
#  6   V6      2848 non-null   float64
#  7   V7      2848 non-null   float64
#  8   V8      2848 non-null   float64
#  9   V9      2848 non-null   float64
#  10  V10     2848 non-null   float64
#  11  V11     2848 non-null   float64
#  12  V12     2848 non-null   float64
#  13  V13     2848 non-null   float64
#  14  V14     2848 non-null   float64
#  15  V15     2848 non-null   float64
#  16  V16     2848 non-null   float64
#  17  V17     2848 non-null   float64
#  18  V18     2848 non-null   float64
#  19  V19     2848 non-null   float64
#  20  V20     2848 non-null   float64
#  21  V21     2848 non-null   float64
#  22  V22     2848 non-null   float64
#  23  V23     2848 non-null   float64
#  24  V24     2848 non-null   float64
#  25  V25     2848 non-null   float64
#  26  V26     2848 non-null   float64
#  27  V27     2848 non-null   float64
#  28  V28     2848 non-null   float64
#  29  Amount  2848 non-null   float64
#  30  Class   2848 non-null   int64
# dtypes: float64(30), int64(1)
# memory usage: 689.9 KB
# None
#        Time        V1        V2        V3        V4        V5        V6  \
# 0  162192.0 -0.328963  1.069914 -1.177616 -1.390025  1.573032 -0.722035
# 1   61316.0  1.324566 -0.573574  0.301133 -0.554045 -1.144552 -1.112693
# 2   79537.0 -0.268992  1.189434  1.694042  1.889089  0.595605  0.409268
# 3  136767.0  1.887015 -0.023258 -2.484910  0.871633  1.322786 -0.114003
# 4  156964.0 -1.100291  0.940355 -0.460443 -1.566820  1.092203 -1.088163
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0  1.534810 -0.191917 -0.402821  ...  0.236054  0.869854 -0.236664  0.261600
# 1 -0.356136 -0.223481 -0.814106  ... -0.580378 -1.349168  0.173841  0.365245
# 2  0.629258  0.069031 -0.946910  ... -0.262243 -0.621264 -0.186591 -0.463225
# 3  0.844374 -0.298111 -0.469164  ...  0.177638  0.328372 -0.227060 -0.275020
# 4  1.640155  0.059671 -1.250144  ...  0.288694  0.568815 -0.380430 -0.238179
#
#         V25       V26       V27       V28  Amount  Class
# 0 -0.226733  0.073891  0.491519  0.335431   20.00      0
# 1  0.007789  0.804080 -0.072368  0.015862   44.95      0
# 2  0.086080 -0.171326  0.042322  0.025788    0.00      0
# 3  0.579419 -0.489052 -0.059647 -0.055287  120.40      0
# 4  0.768274  0.649877 -0.192494 -0.021021   75.19      0
#
# [5 rows x 31 columns]
